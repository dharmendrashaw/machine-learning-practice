# %% [markdown]
# # Machine Learning Zoomcamp
# ## 1.8 Linear algebra refresher
# #### Plan:
#
# - Vector operations
# - Multiplication
#     - Vector-vector multiplication
#     - Matrix-vector multiplication
#     - Matrix-matrix multiplication
# - Identity matrix
# - Inverse

# %%
import numpy as np

# %% [markdown]
# ### Vector Operation

# %%
u = np.array([2, 4, 1, 6])
u
# Out:
# array([2, 4, 1, 6])

# %%
v = np.array([1, 0, 0, 2])
v
# Out:
# array([1, 0, 0, 2])

# %%
2 * u
# Out:
# array([ 4,  8,  2, 12])

# %%
u + v
# Out:
# array([3, 4, 1, 8])

# %%
u * v
# Out:
# array([ 2,  0,  0, 12])

# %% [markdown]
# ### Multiplicatioin

# %%
v.shape
# Out:
# (4,)

# %%
def vector_vector_multiplication(u, v): 
    assert u.shape[0] == v.shape[0]

    result = 0
    n = u.shape[0]
    for i in range(n):
        result = result + (u[i] * v[i])

    return result

# %%
vector_vector_multiplication(u, v)
# Out:
# np.int64(14)

# %%
v.dot(u) # using numpy function
# Out:
# np.int64(14)

# %%
U = np.array([
    [2, 4, 5, 6],
    [1, 2, 1, 2],
    [3, 1, 2, 1],
])
U
# Out:
# array([[2, 4, 5, 6],
#        [1, 2, 1, 2],
#        [3, 1, 2, 1]])

# %%
def matrix_vector_multiplication(U, v):
    assert U.shape[1] == v.shape[0]

    num_rows = U.shape[0]
    result = np.zeros(num_rows)

    for i in range(num_rows):
        result[i] = vector_vector_multiplication(U[i], v)

    return result

# %%
matrix_vector_multiplication(U, v)
# Out:
# array([14.,  5.,  5.])

# %%
U.dot(v) # using numpy funciton
# Out:
# array([14,  5,  5])

# %%
V = np.array([
    [1, 1, 2],
    [0, 0.5, 1], 
    [0, 2, 1],
    [2, 1, 0],
])
V
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
def matrix_matrix_multiplication(U, V):
    assert U.shape[1] == V.shape[0]

    num_rows = U.shape[0]
    num_cols = V.shape[1]

    result = np.zeros((num_rows, num_cols))

    for i in range(num_cols):
        Vi = V[:, i]
        Uvi = matrix_vector_multiplication(U, Vi)
        result[:, i] = Uvi
    return result

# %%
matrix_matrix_multiplication(U, V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %%
U.dot(V)
# Out:
# array([[14. , 20. , 13. ],
#        [ 5. ,  6. ,  5. ],
#        [ 5. ,  8.5,  9. ]])

# %% [markdown]
# ### Identity Matrix

# %%
I = np.eye(3)
I
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
V
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
V.dot(I)
# Out:
# array([[1. , 1. , 2. ],
#        [0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %% [markdown]
# ### Inverse Matrix

# %%
Vs = V[[1,2,3]] # Square matrix
Vs
# Out:
# array([[0. , 0.5, 1. ],
#        [0. , 2. , 1. ],
#        [2. , 1. , 0. ]])

# %%
Vs_inv = np.linalg.inv(Vs) # Inverse of matrix
Vs_inv
# Out:
# array([[ 0.33333333, -0.33333333,  0.5       ],
#        [-0.66666667,  0.66666667,  0.        ],
#        [ 1.33333333, -0.33333333,  0.        ]])

# %%
Vs.dot(Vs_inv) # multiplication of matrix with its inverse will result identity matix
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])
